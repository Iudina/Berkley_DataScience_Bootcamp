# %%
# Dependencies and Setup

# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from matplotlib import style
style.use('fivethirtyeight')

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 635

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

temp, humidity, clouds, wind, city_list, lat, lon, date, country = [], [], [], [], [], [], [], [], []
# Get weather data
for city in cities:
    query_url = url + "&q=" + city
    weather_response = requests.get(query_url)
    
    if weather_response.status_code == 404: #Check response status, skip request if it returns error
        next
    else:
        print(f"Processing Record {cities.index(city)+1} | {city}")
        print(query_url)
        weather_json = weather_response.json()
        city_list.append(city)
        temp.append(weather_json['main']['temp'])
        humidity.append(weather_json['main']['humidity'])
        clouds.append(weather_json['clouds']['all'])
        wind.append(weather_json['wind']['speed'])
        lat.append(weather_json['coord']['lat'])
        lon.append(weather_json['coord']['lon'])
        date.append(weather_json['dt'])
        country.append(weather_json['sys']['country'])
# Out:
# Processing Record 1 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=maldonado
# Processing Record 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=jamestown
# Processing Record 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=port elizabeth
# Processing Record 4 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=arlit
# Processing Record 5 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ushuaia
# Processing Record 6 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=flinders
# Processing Record 8 | sharjah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sharjah
# Processing Record 9 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bethel
# Processing Record 10 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=taltal
# Processing Record 11 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=prince rupert
# Processing Record 12 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=saint george
# Processing Record 14 | zheleznodorozhnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=zheleznodorozhnyy
# Processing Record 15 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=isangel
# Processing Record 16 | zambezi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=zambezi
# Processing Record 17 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kavieng
# Processing Record 18 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mataura
# Processing Record 19 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=turukhansk
# Processing Record 21 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mount gambier
# Processing Record 22 | funadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=funadhoo
# Processing Record 23 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bredasdorp
# Processing Record 25 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=puerto ayora
# Processing Record 26 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mahebourg
# Processing Record 27 | cayhagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cayhagan
# Processing Record 28 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cape town
# Processing Record 29 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=busselton
# Processing Record 30 | gresham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=gresham
# Processing Record 31 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=gamba
# Processing Record 32 | pineto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=pineto
# Processing Record 33 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=hasaki
# Processing Record 34 | batasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=batasan
# Processing Record 35 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=norman wells
# Processing Record 36 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=padang
# Processing Record 37 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=barrow
# Processing Record 38 | magsaysay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=magsaysay
# Processing Record 39 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=arraial do cabo
# Processing Record 40 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=broome
# Processing Record 41 | stawell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=stawell
# Processing Record 42 | lowestoft
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=lowestoft
# Processing Record 43 | qandala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=qandala
# Processing Record 44 | huicheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=huicheng
# Processing Record 46 | bulgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bulgan
# Processing Record 47 | fevik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=fevik
# Processing Record 48 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=fortuna
# Processing Record 49 | contai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=contai
# Processing Record 50 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=qaanaaq
# Processing Record 51 | castrillon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=castrillon
# Processing Record 52 | brookings
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=brookings
# Processing Record 53 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=hobart
# Processing Record 54 | inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=inta
# Processing Record 55 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=nanortalik
# Processing Record 56 | oparino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=oparino
# Processing Record 57 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=talnakh
# Processing Record 58 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=atuona
# Processing Record 59 | haimen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=haimen
# Processing Record 61 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kodiak
# Processing Record 62 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=saint-philippe
# Processing Record 63 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=leshukonskoye
# Processing Record 64 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=port alfred
# Processing Record 65 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bluff
# Processing Record 66 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=tasiilaq
# Processing Record 67 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=yellowknife
# Processing Record 69 | bethlehem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bethlehem
# Processing Record 70 | maunabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=maunabo
# Processing Record 71 | achalpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=achalpur
# Processing Record 72 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=longyearbyen
# Processing Record 74 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sao filipe
# Processing Record 76 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=lata
# Processing Record 77 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=tezu
# Processing Record 78 | kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kupang
# Processing Record 79 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=viedma
# Processing Record 80 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=tiarei
# Processing Record 81 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=rikitea
# Processing Record 82 | cap-aux-meules
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cap-aux-meules
# Processing Record 83 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=alice springs
# Processing Record 84 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=buala
# Processing Record 87 | pokhara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=pokhara
# Processing Record 88 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=muros
# Processing Record 89 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ulladulla
# Processing Record 90 | magistralnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=magistralnyy
# Processing Record 91 | matveyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=matveyevka
# Processing Record 92 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=havoysund
# Processing Record 93 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bathsheba
# Processing Record 94 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=saskylakh
# Processing Record 95 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=avarua
# Processing Record 96 | mont-dore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mont-dore
# Processing Record 97 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=faanui
# Processing Record 98 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=new norfolk
# Processing Record 100 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sobolevo
# Processing Record 101 | xai-xai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=xai-xai
# Processing Record 102 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=hermanus
# Processing Record 103 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ostrovnoy
# Processing Record 104 | praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=praia
# Processing Record 105 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=east london
# Processing Record 106 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=vaini
# Processing Record 107 | ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ayan
# Processing Record 108 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ribeira grande
# Processing Record 109 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=saldanha
# Processing Record 110 | kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kurilsk
# Processing Record 111 | beatrice
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=beatrice
# Processing Record 112 | laukaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=laukaa
# Processing Record 113 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=geraldton
# Processing Record 114 | pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=pochutla
# Processing Record 115 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=hilo
# Processing Record 116 | cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cairns
# Processing Record 117 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=chuy
# Processing Record 118 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=chapais
# Processing Record 119 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=albany
# Processing Record 120 | sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sao gabriel da cachoeira
# Processing Record 121 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=khatanga
# Processing Record 122 | kita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kita
# Processing Record 123 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=srednekolymsk
# Processing Record 124 | zemio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=zemio
# Processing Record 125 | aksarayskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=aksarayskiy
# Processing Record 126 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=pangnirtung
# Processing Record 127 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=souillac
# Processing Record 128 | otane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=otane
# Processing Record 129 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=provideniya
# Processing Record 130 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=butaritari
# Processing Record 131 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=katsuura
# Processing Record 132 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=tessalit
# Processing Record 133 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=punta arenas
# Processing Record 134 | yulin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=yulin
# Processing Record 135 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=amahai
# Processing Record 136 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=xining
# Processing Record 137 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=victoria
# Processing Record 138 | tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=tocopilla
# Processing Record 140 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=tiksi
# Processing Record 141 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=havre-saint-pierre
# Processing Record 142 | santiago de cao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=santiago de cao
# Processing Record 143 | kamaishi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kamaishi
# Processing Record 144 | farah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=farah
# Processing Record 145 | sterling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sterling
# Processing Record 146 | moussoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=moussoro
# Processing Record 147 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bambous virieux
# Processing Record 148 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=chokurdakh
# Processing Record 149 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=abu dhabi
# Processing Record 150 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kaitangata
# Processing Record 151 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=georgetown
# Processing Record 152 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=san patricio
# Processing Record 153 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=san cristobal
# Processing Record 155 | port moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=port moresby
# Processing Record 156 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=thompson
# Processing Record 157 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mar del plata
# Processing Record 158 | senanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=senanga
# Processing Record 159 | kostino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kostino
# Processing Record 160 | chegdomyn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=chegdomyn
# Processing Record 161 | basti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=basti
# Processing Record 162 | san rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=san rafael
# Processing Record 163 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=narsaq
# Processing Record 165 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=luderitz
# Processing Record 166 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=moose factory
# Processing Record 167 | cerro largo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cerro largo
# Processing Record 168 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=yumen
# Processing Record 170 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bilma
# Processing Record 171 | keflavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=keflavik
# Processing Record 172 | la union
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=la union
# Processing Record 173 | akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=akdepe
# Processing Record 174 | astorga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=astorga
# Processing Record 175 | san juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=san juan
# Processing Record 176 | santa maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=santa maria
# Processing Record 177 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ponta do sol
# Processing Record 178 | ust-maya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ust-maya
# Processing Record 179 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=pacific grove
# Processing Record 180 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cabo san lucas
# Processing Record 181 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=namatanai
# Processing Record 182 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kapaa
# Processing Record 183 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=dingle
# Processing Record 185 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=dikson
# Processing Record 186 | labytnangi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=labytnangi
# Processing Record 187 | tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=tecoanapa
# Processing Record 188 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=half moon bay
# Processing Record 190 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kutum
# Processing Record 193 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kavaratti
# Processing Record 194 | orebro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=orebro
# Processing Record 195 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=clyde river
# Processing Record 197 | marigot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=marigot
# Processing Record 200 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=torbay
# Processing Record 201 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=paamiut
# Processing Record 202 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=pevek
# Processing Record 203 | taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=taksimo
# Processing Record 204 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=riyadh
# Processing Record 205 | silver city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=silver city
# Processing Record 206 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sitka
# Processing Record 207 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=samarai
# Processing Record 208 | along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=along
# Processing Record 209 | dali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=dali
# Processing Record 211 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=atar
# Processing Record 212 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=naze
# Processing Record 213 | kindu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kindu
# Processing Record 214 | karatau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=karatau
# Processing Record 215 | eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=eyl
# Processing Record 216 | nyeri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=nyeri
# Processing Record 218 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=grindavik
# Processing Record 220 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=touros
# Processing Record 221 | ferme-neuve
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ferme-neuve
# Processing Record 222 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=north bend
# Processing Record 223 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=shingu
# Processing Record 224 | gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=gornopravdinsk
# Processing Record 225 | maryville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=maryville
# Processing Record 226 | victoria point
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=victoria point
# Processing Record 227 | am timan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=am timan
# Processing Record 228 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=aklavik
# Processing Record 229 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=vila franca do campo
# Processing Record 230 | san andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=san andres
# Processing Record 231 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=san quintin
# Processing Record 233 | new amsterdam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=new amsterdam
# Processing Record 234 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=gat
# Processing Record 235 | phan thiet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=phan thiet
# Processing Record 236 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kahului
# Processing Record 238 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=college
# Processing Record 239 | ouallam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ouallam
# Processing Record 240 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=komsomolskiy
# Processing Record 241 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=severo-kurilsk
# Processing Record 242 | emborion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=emborion
# Processing Record 243 | balsas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=balsas
# Processing Record 244 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=tuatapere
# Processing Record 245 | houma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=houma
# Processing Record 246 | puerto quijarro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=puerto quijarro
# Processing Record 247 | galveston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=galveston
# Processing Record 248 | manchester
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=manchester
# Processing Record 249 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=portland
# Processing Record 250 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=svetlogorsk
# Processing Record 251 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=antofagasta
# Processing Record 252 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=belmonte
# Processing Record 253 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=dicabisagan
# Processing Record 254 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=usinsk
# Processing Record 256 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=tuktoyaktuk
# Processing Record 257 | inverness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=inverness
# Processing Record 259 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cidreira
# Processing Record 260 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=vestmanna
# Processing Record 261 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=qasigiannguit
# Processing Record 262 | cao bang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cao bang
# Processing Record 263 | mugur-aksy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mugur-aksy
# Processing Record 264 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=castro
# Processing Record 265 | kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kiama
# Processing Record 267 | inyonga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=inyonga
# Processing Record 268 | maine-soroa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=maine-soroa
# Processing Record 269 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=vao
# Processing Record 270 | omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=omboue
# Processing Record 271 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sorland
# Processing Record 272 | belaya rechka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=belaya rechka
# Processing Record 273 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=axim
# Processing Record 274 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=berlevag
# Processing Record 275 | labuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=labuan
# Processing Record 276 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=eureka
# Processing Record 277 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=lebu
# Processing Record 278 | kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kamenka
# Processing Record 279 | sokolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sokolo
# Processing Record 281 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=araouane
# Processing Record 282 | meadow lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=meadow lake
# Processing Record 283 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=los llanos de aridane
# Processing Record 284 | traverse city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=traverse city
# Processing Record 286 | baturaja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=baturaja
# Processing Record 287 | ogbomosho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ogbomosho
# Processing Record 288 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=port blair
# Processing Record 289 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=neiafu
# Processing Record 291 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=hobyo
# Processing Record 293 | lengshuijiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=lengshuijiang
# Processing Record 294 | chirkey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=chirkey
# Processing Record 295 | vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=vysokogornyy
# Processing Record 296 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=olinda
# Processing Record 297 | iquitos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=iquitos
# Processing Record 298 | filadelfia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=filadelfia
# Processing Record 299 | dembi dolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=dembi dolo
# Processing Record 300 | mapiripan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mapiripan
# Processing Record 301 | bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bonavista
# Processing Record 302 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=manokwari
# Processing Record 303 | mbuji-mayi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mbuji-mayi
# Processing Record 304 | springbok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=springbok
# Processing Record 305 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=comodoro rivadavia
# Processing Record 306 | gainesville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=gainesville
# Processing Record 307 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=alofi
# Processing Record 308 | khuzdar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=khuzdar
# Processing Record 309 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=fukue
# Processing Record 311 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=coquimbo
# Processing Record 312 | santiago del estero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=santiago del estero
# Processing Record 313 | salamanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=salamanca
# Processing Record 314 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=san carlos de bariloche
# Processing Record 315 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=vila velha
# Processing Record 317 | suarez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=suarez
# Processing Record 318 | iguatemi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=iguatemi
# Processing Record 319 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=hithadhoo
# Processing Record 320 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=necochea
# Processing Record 321 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=namibe
# Processing Record 322 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=beloha
# Processing Record 323 | yuanping
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=yuanping
# Processing Record 324 | yaguajay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=yaguajay
# Processing Record 325 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cayenne
# Processing Record 326 | salamiyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=salamiyah
# Processing Record 327 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=roma
# Processing Record 328 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=saint-francois
# Processing Record 329 | juli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=juli
# Processing Record 330 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=upernavik
# Processing Record 331 | pucallpa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=pucallpa
# Processing Record 332 | north platte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=north platte
# Processing Record 333 | parintins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=parintins
# Processing Record 335 | hispania
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=hispania
# Processing Record 336 | visnes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=visnes
# Processing Record 337 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sept-iles
# Processing Record 338 | finschhafen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=finschhafen
# Processing Record 339 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=camacha
# Processing Record 340 | zaozerne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=zaozerne
# Processing Record 341 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=carnarvon
# Processing Record 342 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mareeba
# Processing Record 343 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=tomatlan
# Processing Record 344 | sabha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sabha
# Processing Record 345 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=guerrero negro
# Processing Record 346 | griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=griffith
# Processing Record 347 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ilulissat
# Processing Record 348 | navahrudak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=navahrudak
# Processing Record 351 | karaton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=karaton
# Processing Record 352 | baleshwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=baleshwar
# Processing Record 353 | fez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=fez
# Processing Record 354 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=nome
# Processing Record 355 | aleksandrovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=aleksandrovka
# Processing Record 356 | high prairie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=high prairie
# Processing Record 357 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=adrar
# Processing Record 358 | jiwani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=jiwani
# Processing Record 359 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=hamilton
# Processing Record 360 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cockburn town
# Processing Record 361 | carnot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=carnot
# Processing Record 362 | kings mountain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kings mountain
# Processing Record 363 | cruzeiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cruzeiro
# Processing Record 364 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=dwarka
# Processing Record 365 | bichura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bichura
# Processing Record 366 | bela palanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bela palanka
# Processing Record 367 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=nikolskoye
# Processing Record 368 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sangar
# Processing Record 369 | srivardhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=srivardhan
# Processing Record 370 | tamandare
# ...
# Processing Record 511 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=hofn
# Processing Record 512 | bar harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bar harbor
# Processing Record 513 | jurilovca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=jurilovca
# Processing Record 515 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=erenhot
# Processing Record 516 | abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=abha
# Processing Record 517 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=udachnyy
# Processing Record 518 | staryy nadym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=staryy nadym
# Processing Record 520 | murrhardt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=murrhardt
# Processing Record 521 | barra da estiva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=barra da estiva
# Processing Record 522 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=vostok
# Processing Record 523 | gusau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=gusau
# Processing Record 524 | monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=monrovia
# Processing Record 525 | kharian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kharian
# Processing Record 526 | russkaya polyana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=russkaya polyana
# Processing Record 528 | bucerias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bucerias
# Processing Record 529 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ketchikan
# Processing Record 530 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=rawson
# Processing Record 531 | calama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=calama
# Processing Record 532 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=marsa matruh
# Processing Record 533 | shakhovskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=shakhovskaya
# Processing Record 534 | jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=jacareacanga
# Processing Record 535 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=okhotsk
# Processing Record 536 | oum hadjer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=oum hadjer
# Processing Record 537 | ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ossora
# Processing Record 538 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=taoudenni
# Processing Record 539 | channel-port aux basques
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=channel-port aux basques
# Processing Record 540 | innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=innisfail
# Processing Record 541 | handan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=handan
# Processing Record 542 | dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=dhidhdhoo
# Processing Record 543 | shirokaya rechka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=shirokaya rechka
# Processing Record 546 | bujaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bujaru
# Processing Record 547 | san vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=san vicente
# Processing Record 549 | altamont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=altamont
# Processing Record 550 | aljezur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=aljezur
# Processing Record 551 | bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bereda
# Processing Record 552 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=tromso
# Processing Record 553 | troitsko-pechorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=troitsko-pechorsk
# Processing Record 554 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kruisfontein
# Processing Record 555 | lokoja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=lokoja
# Processing Record 556 | muyezerskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=muyezerskiy
# Processing Record 558 | sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sambava
# Processing Record 560 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=esperance
# Processing Record 561 | palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=palana
# Processing Record 562 | seydi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=seydi
# Processing Record 563 | cabatuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cabatuan
# Processing Record 564 | road town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=road town
# Processing Record 565 | yerofey pavlovich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=yerofey pavlovich
# Processing Record 567 | esmeraldas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=esmeraldas
# Processing Record 568 | carhuaz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=carhuaz
# Processing Record 569 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sur
# Processing Record 570 | dunmore town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=dunmore town
# Processing Record 571 | villa carlos paz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=villa carlos paz
# Processing Record 572 | chillicothe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=chillicothe
# Processing Record 574 | mashhad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mashhad
# Processing Record 575 | alugan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=alugan
# Processing Record 576 | madiun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=madiun
# Processing Record 577 | aras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=aras
# Processing Record 578 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sioux lookout
# Processing Record 579 | benito juarez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=benito juarez
# Processing Record 580 | bundaberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=bundaberg
# Processing Record 582 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kaeo
# Processing Record 583 | umea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=umea
# Processing Record 584 | ankang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ankang
# Processing Record 585 | pilar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=pilar
# Processing Record 586 | greece
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=greece
# Processing Record 587 | verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=verkhnyaya inta
# Processing Record 588 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=oranjemund
# Processing Record 589 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=walvis bay
# Processing Record 590 | puerto narino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=puerto narino
# Processing Record 591 | carandai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=carandai
# Processing Record 592 | kaili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=kaili
# Processing Record 594 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=batemans bay
# Processing Record 595 | narang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=narang
# Processing Record 596 | north branch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=north branch
# Processing Record 597 | denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=denpasar
# Processing Record 598 | amambai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=amambai
# Processing Record 599 | villa sandino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=villa sandino
# Processing Record 601 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=caravelas
# Processing Record 602 | springfield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=springfield
# Processing Record 603 | podor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=podor
# Processing Record 604 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=virginia beach
# Processing Record 605 | mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mao
# Processing Record 606 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=rio grande
# Processing Record 607 | neuquen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=neuquen
# Processing Record 608 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=iqaluit
# Processing Record 609 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mehamn
# Processing Record 610 | cleburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=cleburne
# Processing Record 611 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=grand gaube
# Processing Record 612 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ahipara
# Processing Record 613 | san carlos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=san carlos
# Processing Record 614 | rjukan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=rjukan
# Processing Record 616 | czestochowa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=czestochowa
# Processing Record 617 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=ambilobe
# Processing Record 618 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=belyy yar
# Processing Record 619 | barinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=barinas
# Processing Record 620 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=mayo
# Processing Record 621 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=northam
# Processing Record 622 | jiazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=jiazi
# Processing Record 623 | oxford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=oxford
# Processing Record 624 | beyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=beyla
# Processing Record 625 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=skjervoy
# Processing Record 626 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=hami
# Processing Record 627 | saquisili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=saquisili
# Processing Record 628 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=sisimiut
# Processing Record 629 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=tautira
# Processing Record 631 | apache junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=apache junction
# Processing Record 633 | barmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=barmer
# Processing Record 634 | trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=trinidad
# Processing Record 635 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e70a1ffc1fcf0323d57ab546ca5e1a&q=leningradskiy

# %%
df = pd.DataFrame({"City": city_list, "Country": country, "Temperature, F": temp, "Humidity (%)": humidity, 
                   "Cloudiness (%)" : clouds, "Wind Speed, mph": wind, "Latitude": lat, 
                   "Longitude": lon, "Date": date})
df = df[df['Humidity (%)'] < 100]
print(f"Request was processed for {len(city_list)} cities")
df.to_csv('out.csv')
df.head()
# Out:
# Request was processed for 560 cities
#              City  Cloudiness (%) Country        Date  Humidity (%)  Latitude  \
# 0       maldonado              20      UY  1536087600            67    -34.91
# 1       jamestown               0      AU  1536088762            52    -33.21
# 2  port elizabeth              20      US  1536087360            57     39.31
# 3           arlit              36      NE  1536089196            31     18.74
# 4         ushuaia              75      AR  1536087600            84    -54.81
#
#    Longitude  Temperature, F  Wind Speed, mph
# 0     -54.96           59.00            11.41
# 1     138.60           38.89            10.00
# 2     -74.98           92.61             4.07
# 3       7.39           91.18             3.51
# 4     -68.31           33.96            26.40

# %%
# Latitude vs. Temperature scatterplot
trend1 = f"Observed Trend 1: \n" +\
"This scatter plot demonstrates a correlation between Latitude and Temperatures\n" +\
"with temperatures being higher as we approach to the Equator.\n" +\
"However the Equator (or 0 Latitude) is not the peak point of the trend.\n" +\
"The highest temperatures were observed from 20 to 40 northern latitude\n" +\
"which is actually in line with our expectations.\n" +\
"Equatorial zone is a zone with tropical humid climate where temperatures do not \n" +\
"vary significantly during the year. Whilst the area of 20-40 northern latitude is a \n" +\
"zone of arid and semi-arid climate (Saudi Arabia, Sudan, Iraq etc) with \n" +\
"extremely hot weather in Summer. Our observation took part in the middle July. \n" +\
"Same observation performed during the year would move a peak point around \n" +\
"the Equator shifting towards Southern Hemisphere during the Winter."
print(trend1)
plt.figure(figsize=(8,6))
plt.scatter(lat, temp, marker="o", facecolors = "darkblue")
# plt.grid()
plt.title(f"City Latitude vs. Temperature {str(datetime.datetime.today()).split()[0]}")
plt.xlabel("Latitude", fontsize=18)
plt.ylabel("Tempereture (F)", fontsize=18)
# plt.text(90, 25, trend1, fontsize=14,)
plt.savefig("LatitudeVsTemperature.png")

plt.show()
# Out:
# Observed Trend 1:
# This scatter plot demonstrates a correlation between Latitude and Temperatures
# with temperatures being higher as we approach to the Equator.
# However the Equator (or 0 Latitude) is not the peak point of the trend.
# The highest temperatures were observed from 20 to 40 northern latitude
# which is actually in line with our expectations.
# Equatorial zone is a zone with tropical humid climate where temperatures do not
# vary significantly during the year. Whilst the area of 20-40 northern latitude is a
# zone of arid and semi-arid climate (Saudi Arabia, Sudan, Iraq etc) with
# extremely hot weather in Summer. Our observation took part in the middle July.
# Same observation performed during the year would move a peak point around
# the Equator shifting towards Southern Hemisphere during the Winter.

# %%
# Latitude vs. Humidity scatterplot\
trend2 = f"Observed Trend 2: \n" +\
"This scatterplot is not very represenatative. This can be explained by the fact \n" +\
"that Humidity is driven mostly by closeness to the ocean, season (dry or wet \n" +\
"in South East Asia) etc. rather than Latitude It can be 90% Humid deep in Siberia and \n" +\
"in Thailand. In this case scatterplot Humidity vs Longitude could be be more illustrative. \n" +\
"Please, see next chart."
print(trend2)
plt.scatter(df['Latitude'], df['Humidity (%)'], marker="o", facecolors = "darkblue")
# plt.grid()
plt.title(f"City Latitude vs. Humidity {str(datetime.datetime.today()).split()[0]}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# plt.text(90, 70, trend2, fontsize=14,)
plt.savefig("latitudeVsHumidity.png")

plt.show()
# Out:
# Observed Trend 2:
# This scatterplot is not very represenatative. This can be explained by the fact
# that Humidity is driven mostly by closeness to the ocean, season (dry or wet
# in South East Asia) etc. rather than Latitude It can be 90% Humid deep in Siberia and
# in Thailand. In this case scatterplot Humidity vs Longitude could be be more illustrative.
# Please, see next chart.

# %%
# Longitude vs. Humidity scatterplot
trend3 = f"Observed Trend 3: \n" +\
"There is some pattern here. Humidity 80%-100% is cocentrated in the area \n" +\
"of -100~-50 Longitude and 0~50 Longitude. We traced it to a Goole map and it \n" +\
"turned to be Pacific coast of Americas, Atlantic coast of Americas and Atlantic \n" +\
"coast of Europe (Great Britain etc.) A lot of observations concentrated around the \n" +\
"point of 80% Humidity in 100~110 Longitude which is a humid South-East Asia region \n" +\
"surrounded by Idian ocean. In my opinion this Graph is more representative and looks  \n" +\
"like a World Ocean map though still it doesn't cover many factors.\n"
print(trend3)
plt.scatter(df['Longitude'], df['Humidity (%)'], marker="o", facecolors = "darkred")
# plt.grid()
plt.title(f"City Longitude vs. Humidity {str(datetime.datetime.today()).split()[0]}")
plt.xlabel("Longitude")
plt.ylabel("Humidity (%)")
# plt.text(210, 45, trend3, fontsize=14,)
plt.savefig("LongitudeVsHumidity.png")

plt.show()
# Out:
# Observed Trend 3:
# There is some pattern here. Humidity 80%-100% is cocentrated in the area
# of -100~-50 Longitude and 0~50 Longitude. We traced it to a Goole map and it
# turned to be Pacific coast of Americas, Atlantic coast of Americas and Atlantic
# coast of Europe (Great Britain etc.) A lot of observations concentrated around the
# point of 80% Humidity in 100~110 Longitude which is a humid South-East Asia region
# surrounded by Idian ocean. In my opinion this Graph is more representative and looks
# like a World Ocean map though still it doesn't cover many factors.

# %%
# Latitude vs. Cloudiness scatterplot
trend4 = f"Observed Trend 4: \n" +\
"There is no trend on this scatterplot that could demonstrate us any  \n" +\
"realation between Latitude and Cloudiness. Maybe results would be \n" +\
"more representative if we observed data at the same time of the day (at noon for example). \n" +\
"No conclusions can be made based on this scatterplot."
print (trend4)
plt.scatter(lat, clouds, marker="o", facecolors = "darkblue")
# plt.grid()
plt.title(f"City Latitude vs. Cloudiness {str(datetime.datetime.today()).split()[0]}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# plt.text(90, 70, trend4, fontsize=14,)
plt.savefig("LatitudeVsCloudiness.png")

plt.show()
# Out:
# Observed Trend 4:
# There is no trend on this scatterplot that could demonstrate us any
# realation between Latitude and Cloudiness. Maybe results would be
# more representative if we observed data at the same time of the day (at noon for example).
# No conclusions can be made based on this scatterplot.

# %%
# Latitude vs. Wind Speed scatterplot
windmean = round(df["Wind Speed, mph"].mean(),2)
trend5 = f"Observed Trend 5: \n" +\
f"There is no trend on this scatterplot that could demonstrate us any realation \n" +\
f"between Latitude and Wind Speed. We can only see that the observed data \n"  +\
f"concentrated arount the average of {windmean} mph regardless of Latitudes \n"  +\
f"with some ouliers that gan be ignored in this study."
print(trend5)
plt.scatter(lat, wind, marker="o", facecolors = "darkblue")
# plt.grid()
plt.title(f"City Latitude vs. Wind Speed (mph) {str(datetime.datetime.today()).split()[0]}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# plt.text(90, 20, trend5, fontsize=14,)
plt.savefig("LatitudeVsWindSpeed.png")

plt.show()
# Out:
# Observed Trend 5:
# There is no trend on this scatterplot that could demonstrate us any realation
# between Latitude and Wind Speed. We can only see that the observed data
# concentrated arount the average of 8.38 mph regardless of Latitudes
# with some ouliers that gan be ignored in this study.
